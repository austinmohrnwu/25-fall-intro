# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

import warnings
warnings.simplefilter("ignore")

# %%
survey = Table.read_table('media2.csv')
survey = survey.select(6, 7, 8)
survey = survey.relabeled(0, 'movie')
survey = survey.relabeled(1, 'music')
survey = survey.relabeled(2, 'games')
survey.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>movie</th> <th>music</th> <th>games</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Comedy         </td> <td>Jazz          </td> <td>Strategy/Puzzles</td>
#         </tr>
#         <tr>
#             <td>Action/Thriller</td> <td>Country       </td> <td>Action/Adventure</td>
#         </tr>
#         <tr>
#             <td>Sci-Fi/Fantasy </td> <td>Rap/Pop/Techno</td> <td>Action/Adventure</td>
#         </tr>
#         <tr>
#             <td>Action/Thriller</td> <td>Country       </td> <td>Action/Adventure</td>
#         </tr>
#         <tr>
#             <td>Horror/Mystery </td> <td>Country       </td> <td>Action/Adventure</td>
#         </tr>
#     </tbody>
# </table>
# <p>... (19 rows omitted)</p>

# %%
grouped_movie = survey.group('movie')
grouped_movie.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>movie</th> <th>count</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Action/Thriller   </td> <td>8    </td>
#         </tr>
#         <tr>
#             <td>Comedy            </td> <td>6    </td>
#         </tr>
#         <tr>
#             <td>Don't watch movies</td> <td>1    </td>
#         </tr>
#         <tr>
#             <td>Drama/Romance     </td> <td>1    </td>
#         </tr>
#         <tr>
#             <td>Horror/Mystery    </td> <td>2    </td>
#         </tr>
#         <tr>
#             <td>Sci-Fi/Fantasy    </td> <td>6    </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# text
